# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style
# Out:
# <module 'matplotlib.style' from 'C:\\Users\\nicka\\anaconda3\\lib\\site-packages\\matplotlib\\style\\__init__.py'>

# %%
df = pd.read_csv('./Databreaches.csv') #reading csv and we save it into a variable
df.head()
# Out:
#                                               Entity  \
# 0                                South Africa police
# 1                        Morgan Stanley Smith Barney
# 2                                    Yale University
# 3                                        US Military
# 4  Service Personnel and Veterans Agency - United...
#
#                                          Description    Year Records Leaked  \
# 0  Hacker collective 'Anonymous' hacked an anonym...  2013.0         16,000
# 1  Morgan Stanley mailed a CD containing sensitiv...  2011.0         34,000
# 2                                                NaN  2010.0         43,000
# 3                                                NaN  2011.0         50,000
# 4  Stolen USBs containing personal information ab...  2008.0         50,500
#
#   Target Organization              Type Method of Leak  \
# 0          Government                           Hacked
# 1           Financial  Lost / Stolen Computer or Media
# ...

# %%
data_frame.shape
# Out:
# (173, 9)

# %%
df.loc[1]
# Out:
# Entity                                       Morgan Stanley Smith Barney
# Description            Morgan Stanley mailed a CD containing sensitiv...
# Year                                                                2011
# Records Leaked                                                    34,000
# Target Organization                                            Financial
# Type Method of Leak                      Lost / Stolen Computer or Media
# Data Sensitivity                              3. Credit card information
# Sources Link           http://www.idtheftcenter.org/artman2/publish/l...
# Sources Name                                                        ITRC
# Name: 1, dtype: object

# %%
df[["Type Method of Leak", "Target Organization", "Description", "Records Leaked", "Data Sensitivity"]]
# Out:
#                  Type Method of Leak Target Organization  \
# 0                             Hacked          Government
# 1    Lost / Stolen Computer or Media           Financial
# 2             Accidentally Published            Academic
# 3             Accidentally Published            Military
# 4    Lost / Stolen Computer or Media          Government
# ..                               ...                 ...
# 168                           Hacked           Financial
# 169                           Hacked           Financial
# 170                           Hacked                 Web
# 171                           Hacked              Gaming
# 172                              NaN                 NaN
#
#                                            Description Records Leaked  \
# 0    Hacker collective 'Anonymous' hacked an anonym...         16,000
# 1    Morgan Stanley mailed a CD containing sensitiv...         34,000
# ...

# %%
df[["Target Organization", "Records Leaked", "Data Sensitivity"]]
# Out:
#     Target Organization Records Leaked  \
# 0            Government         16,000
# 1             Financial         34,000
# 2              Academic         43,000
# 3              Military         50,000
# 4            Government         50,500
# ..                  ...            ...
# 168           Financial        unknown
# 169           Financial        unknown
# 170                 Web        unknown
# 171              Gaming        unknown
# 172                 NaN            NaN
#
#                                     Data Sensitivity
# 0                      2 SSN and/or personal details
# 1                         3. Credit card information
# 2                      2 SSN and/or personal details
# 3    1. Just email address and/or online information
# 4                      2 SSN and/or personal details
# ..                                               ...
# 168  1. Just email address and/or online information
# 169  1. Just email address and/or online information
# ...
